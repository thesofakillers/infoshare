# %% [markdown]
# # Finding Candidate Words for LexicalSample WSD
#
# We now inspect the Semcor dataset for "candidate words" for Lexical sample WSD (LSWSD). Here, we restrict ourselves to the following criteria:
#
# 1. we only consider 20-30ish possible lemmas
# 2. each considered lemma should have around 3 possible senses
# 3. each considered lemma should have multiple POS tags.
# 4. There should be at least hundreds of samples per lemma.
# 5. For each lemma, the distribution of senses should be as flat as possible.
#     - For example, if a word has senses 1, 2, and 3, there should be roughly
#       the same number of examples for each sense of the word.

# %%
import datasets
import pandas as pd

# %%
from collections import Counter

# %%
from typing import List

# %%
from scipy.stats import entropy

# %%
from IPython.display import display

# %%
# first, download and gather the SemCor dataset
semcor = datasets.load_dataset("thesofakillers/SemCor")

brown1 = semcor["brown1"].to_pandas()
brown1 = brown1.replace(to_replace="None", value=None)

brown2 = semcor["brown2"].to_pandas()
brown2 = brown2.replace(to_replace="None", value=None)

brownv = semcor["brownv"].to_pandas()
brownv = brownv.replace(to_replace="None", value=None)

# we now have all the data in the raganato train set in one pd df
semcor_df = pd.concat([brown1, brown2, brownv])
# Out:
# Using custom data configuration thesofakillers--SemCor-d701cc7e0f131929
# Reusing dataset csv (/Users/thesofakillers/.cache/huggingface/datasets/thesofakillers___csv/thesofakillers--SemCor-d701cc7e0f131929/0.0.0/433e0ccc46f9880962cc2b12065189766fbb2bee57a221866138fb9203c83519)
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
semcor_df
# Out:
#        tagfile  pnum  snum   tag   lemma      lexsn  wnsn       value     cmd  \
# 0       br-j54     1     1    wf    None       None  None    Whenever  ignore
# 1       br-j54     1     1    wf  artist  1:18:00::     1     artists    done
# 2       br-j54     1     1  punc    None       None  None           ,    None
# 3       br-j54     1     1    wf    None       None  None      indeed    done
# 4       br-j54     1     1  punc    None       None  None           ,    None
# ...        ...   ...   ...   ...     ...        ...   ...         ...     ...
# 364294  br-b22    26    88    wf    None       None  None          by  ignore
# 364295  br-b22    26    88    wf    None       None  None         the  ignore
# 364296  br-b22    26    88    wf    None       None  None   Christian     tag
# 364297  br-b22    26    88    wf    None       None  None  imperative     tag
# 364298  br-b22    26    88  punc    None       None  None           .    None
#
#           dc     ot    pn   pos   rdf   sep
# 0       None   None  None   WRB  None  None
# 1       None   None  None    NN  None  None
# 2       None   None  None  None  None  None
# 3       None  notag  None    RB  None  None
# 4       None   None  None  None  None  None
# ...      ...    ...   ...   ...   ...   ...
# 364294  None   None  None    IN  None  None
# 364295  None   None  None    DT  None  None
# 364296  None   None  None   NNP  None  None
# 364297  None   None  None    JJ  None  None
# 364298  None   None  None  None  None  None
#
# [778587 rows x 15 columns]

# %%
lemma_counts = semcor_df.lemma.value_counts()
lemma_counts.name = 'lemma_count'

# %%
def flatness(string_list: List[str]) -> float:
    return entropy(list(Counter(string_list).values()))

# %%
lemma_sense_pos = semcor_df.groupby("lemma").agg(
    sense_count=pd.NamedAgg(column='lexsn', aggfunc='nunique'), 
    pos_count=pd.NamedAgg(column='pos', aggfunc='nunique'),
    sense_flatness=pd.NamedAgg(column='lexsn', aggfunc=flatness),
    senses=pd.NamedAgg(column='lexsn', aggfunc=Counter)
)

# %%
candidate_data = pd.concat([lemma_counts, lemma_sense_pos], axis=1)

# %%
# filter for criterion 2
candidate_data = candidate_data[
    (candidate_data.sense_count >= 3) & (candidate_data.sense_count <= 6)
]

# filter for criterion 3
candidate_data = candidate_data[candidate_data.pos_count >= 2]

# filter for criterion 4
candidate_data = candidate_data[candidate_data.lemma_count >= 100]

# sort for criterion 5
candidate_data.sort_values(["sense_flatness"], ascending=False, inplace=True)

# %%
# top 30 for criterion 1
with pd.option_context('display.max_rows', 30):
    display(candidate_data[:30])
# Out:
#             lemma_count  sense_count  pos_count  sense_flatness  \
# result              214            5          2        1.498573
# just                327            6          2        1.394321
# individual          114            6          2        1.362867
# most                350            6          3        1.298100
# local               116            5          2        1.227815
# public              109            5          2        1.207541
# same                243            5          2        1.167289
# cost                136            5          2        1.166130
# express             100            6          3        1.147828
# now                 459            6          2        1.121687
# fear                103            5          2        1.098035
# attempt             108            4          2        1.076350
# less                125            4          3        1.069885
# second              157            6          3        1.053059
# rate                120            6          2        1.029436
# no                  152            4          3        1.023440
# once                115            4          2        1.017905
# then                489            5          3        0.996542
# plant               110            5          2        0.990971
# list                107            4          2        0.988444
# pressure            103            6          2        0.966498
# today               103            4          2        0.958775
# program             157            6          2        0.957422
# next                127            4          2        0.955235
# permit              100            4          2        0.914824
# some                151            5          2        0.856227
# later               128            4          2        0.853386
# enough              161            3          3        0.851373
# here                257            5          2        0.842518
# age                 106            5          2        0.826849
#
#                                                        senses
# result      {'1:19:00::': 82, '2:42:00::': 45, '1:11:00::'...
# just        {'4:02:01::': 50, '4:02:05::': 85, '4:02:00::'...
# individual  {'5:00:00:independent:00': 8, '3:00:00::': 38,...
# most        {'4:02:00::': 177, '4:02:01::': 60, '3:00:02::...
# local       {'3:00:01::': 47, '3:00:03::': 39, '5:00:00:na...
# public      {'3:00:00::': 48, '1:14:00::': 35, '5:00:00:co...
# same        {'3:00:02::': 124, '3:00:00::': 78, '3:00:04::...
# cost        {'2:42:00::': 35, '1:21:00::': 75, '1:07:01::'...
# express     {'2:32:01::': 53, '4:02:00::': 1, '2:32:00::':...
# now         {'4:02:00::': 182, '4:02:05::': 223, '1:28:00:...
# fear        {'1:12:00::': 61, '1:12:01::': 4, '2:37:00::':...
# attempt     {'2:41:00::': 46, '1:04:00::': 45, '2:36:00::'...
# less        {'3:00:00::': 39, '1:23:00::': 7, '4:02:00::':...
# second      {'5:00:00:ordinal:00': 107, '1:28:00::': 24, '...
# rate        {'1:28:00::': 68, '1:21:00::': 39, '2:31:01::'...
# no          {'3:00:00::': 90, '4:02:02::': 37, '1:10:00::'...
# once        {'4:02:00::': 70, '4:02:01::': 20, '4:02:02::'...
# then        {'4:02:01::': 81, '4:02:02::': 104, '4:02:00::...
# plant       {'1:03:00::': 36, '1:06:01::': 63, '2:35:01::'...
# list        {'1:10:00::': 64, '2:32:00::': 23, '2:41:00::'...
# pressure    {'1:09:00::': 1, '1:19:00::': 65, '1:07:00::':...
# today       {'1:28:00::': 69, '4:02:01::': 19, '4:02:00::'...
# program     {'1:09:00::': 106, '1:10:04::': 3, '1:10:01::'...
# next        {'5:00:00:succeeding(a):00': 85, '4:02:00::': ...
# permit      {'2:32:00::': 54, '2:41:00::': 39, '1:10:02::'...
# some        {'3:00:00::': 100, '5:00:00:many:00': 5, '5:00...
# later       {'5:00:00:subsequent:00': 16, '4:02:02::': 17,...
# enough      {'4:02:00::': 100, '1:23:00::': 12, '5:00:00:s...
# here        {'4:02:02::': 87, '4:02:00::': 158, '4:02:01::...
# age         {'1:28:02::': 23, '1:07:00::': 75, '2:30:01::'...

# %%
pd.set_option('display.max_rows', 10)
candidate_data
# Out:
#             lemma_count  sense_count  pos_count  sense_flatness  \
# result              214            5          2        1.498573
# just                327            6          2        1.394321
# individual          114            6          2        1.362867
# most                350            6          3        1.298100
# local               116            5          2        1.227815
# ...                 ...          ...        ...             ...
# die                 137            5          2        0.308226
# young               103            3          2        0.302305
# kind                123            4          2        0.237229
# group              1334            5          4        0.034383
# location            993            3          2        0.029025
#
#                                                        senses
# result      {'1:19:00::': 82, '2:42:00::': 45, '1:11:00::'...
# just        {'4:02:01::': 50, '4:02:05::': 85, '4:02:00::'...
# individual  {'5:00:00:independent:00': 8, '3:00:00::': 38,...
# most        {'4:02:00::': 177, '4:02:01::': 60, '3:00:02::...
# local       {'3:00:01::': 47, '3:00:03::': 39, '5:00:00:na...
# ...                                                       ...
# die         {'2:30:00::': 128, '1:06:00::': 6, '2:37:00::'...
# young       {'3:00:00::': 95, '5:00:00:early:02': 1, '1:05...
# kind        {'1:09:00::': 117, '3:00:00::': 4, '5:00:00:be...
# group       {'1:03:00::': 1328, '2:31:00::': 3, '1:27:00::...
# location    {'1:03:00::': 989, '1:04:01::': 2, '1:04:02::'...
#
# [51 rows x 5 columns]

# %%
# and we save to disk, to use later
with open("swsd_lemmas.txt", "w") as f:
    f.write("\n".join(candidate_data[:30].index.tolist()))
